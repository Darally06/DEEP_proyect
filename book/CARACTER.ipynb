# %%
# [Config] Librerías
import pandas as pd
import os
import nibabel as nib
import re
import numpy as np
import pandas as pd
from datetime import datetime
import subprocess
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# [Config] Rutas
df_tab = pd.read_csv("../Data/TABULAR.csv")
df_dx = pd.read_csv('../Data/ANDI_out.csv')

# %% [markdown]
# ## Correlación de las variables clínicas con la variable objetivo

# %%
var_2 = [
    'is_dementia',  
    'APOE4_std', 'CDRSB_std', 'MMSE_std', 'ADAS13_std',
    'FAQ_std', 'RAVLT_immediate_std', 'RAVLT_learning_std',
    'RAVLT_forgetting_std', 'DIGITSCOR_std', 'TRABSCOR_std',
]

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df_tab[var_2].corr(), annot=True, fmt=".2f", cmap="GnBu")
plt.title("Matriz de correlaciones de Biomarcadores")
plt.show()

# %%
var_3 = [
    'is_dementia', 
    'Ventricles_std', 'Hippocampus_std', 'WholeBrain_std', 'Entorhinal_std',
    'Fusiform_std', 'MidTemp_std', 'ICV_std'
]

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df_tab[var_3].corr(), annot=True, fmt=".2f", cmap="GnBu")
plt.title("Matriz de correlaciones de Biomarcadores")
plt.show()
